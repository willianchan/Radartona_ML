# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Willian/Desktop/Radartona/bases_tratadas/velocidades.csv', sep=";")

# %%
df.head()
# Out:
#    id_radar  velocidade   ano  mes  dia  hora  minuto  velocidade_maxima
# 0      4560          56  2019    2   11     8      59               50.0
# 1      6792         100  2018    2   12     8      35               55.0
# 2      4489         108  2018    2   12     9      19               50.0
# 3      4306         114  2018    2   12     9      23               50.0
# 4      4265         111  2018    2   12     9      36               50.0

# %%
df_clima = pd.read_json ('C:/Users/Willian/Desktop/Radartona/Radartona_ML/bases/open_w.json')

# %%
df_clima.head()
# Out:
#    city_id                                               main  \
# 0  3448439  {'temp': 295.375, 'temp_min': 295.375, 'temp_m...
# 1  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 2  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 3  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 4  3448439  {'temp': 293.192, 'temp_min': 293.192, 'temp_m...
#
#                        wind                         rain       clouds  \
# 0  {'speed': 1, 'deg': 325}  {'1h': 0.30000000000000004}  {'all': 24}
# 1  {'speed': 1, 'deg': 336}                          NaN  {'all': 20}
# 2  {'speed': 1, 'deg': 336}                          NaN  {'all': 20}
# 3  {'speed': 1, 'deg': 336}                          NaN  {'all': 20}
# 4  {'speed': 1, 'deg': 343}                          NaN  {'all': 12}
#
#                                              weather          dt  \
# 0  [{'id': 500, 'main': 'Rain', 'description': 'l...  1420070400
# ...

# %%
df_clima["weather"][0][0]["main"]
# Out:
# 'Rain'

# %%
for index, row in df_clima.iterrows():
    main = row["weather"][0]["main"]
    if main == "Rain":
        r = 1
    else:
        r = 0
        
    df_clima.loc[index, 'rain'] = r

# %%
df_clima.head()
# Out:
#    city_id                                               main  \
# 0  3448439  {'temp': 295.375, 'temp_min': 295.375, 'temp_m...
# 1  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 2  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 3  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 4  3448439  {'temp': 293.192, 'temp_min': 293.192, 'temp_m...
#
#                        wind  rain       clouds  \
# 0  {'speed': 1, 'deg': 325}     1  {'all': 24}
# 1  {'speed': 1, 'deg': 336}     0  {'all': 20}
# 2  {'speed': 1, 'deg': 336}     0  {'all': 20}
# 3  {'speed': 1, 'deg': 336}     0  {'all': 20}
# 4  {'speed': 1, 'deg': 343}     0  {'all': 12}
#
#                                              weather          dt  \
# 0  [{'id': 500, 'main': 'Rain', 'description': 'l...  1420070400
# 1  [{'id': 801, 'main': 'Clouds', 'description': ...  1420074000
# 2  [{'id': 801, 'main': 'Clouds', 'description': ...  1420077600
# ...

# %%
for index, row in df_clima.iterrows():
    ano, mes, dia = list(map(int, row["dt_iso"][:10].split("-")))
    
    df_clima.loc[index, 'ano'] = ano
    df_clima.loc[index, 'mes'] = mes
    df_clima.loc[index, 'dia'] = dia

# %%
df_clima['dia'] = df_clima['dia'].astype(int)

# %%
df_clima.head()
# Out:
#    city_id                                               main  \
# 0  3448439  {'temp': 295.375, 'temp_min': 295.375, 'temp_m...
# 1  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 2  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 3  3448439  {'temp': 293.636, 'temp_min': 293.636, 'temp_m...
# 4  3448439  {'temp': 293.192, 'temp_min': 293.192, 'temp_m...
#
#                        wind  rain       clouds  \
# 0  {'speed': 1, 'deg': 325}     1  {'all': 24}
# 1  {'speed': 1, 'deg': 336}     0  {'all': 20}
# 2  {'speed': 1, 'deg': 336}     0  {'all': 20}
# 3  {'speed': 1, 'deg': 336}     0  {'all': 20}
# 4  {'speed': 1, 'deg': 343}     0  {'all': 12}
#
#                                              weather          dt  \
# 0  [{'id': 500, 'main': 'Rain', 'description': 'l...  1420070400
# 1  [{'id': 801, 'main': 'Clouds', 'description': ...  1420074000
# 2  [{'id': 801, 'main': 'Clouds', 'description': ...  1420077600
# ...

# %%
df_clima.to_csv('C:/Users/Willian/Desktop/Radartona/bases_tratadas/clima_tratado.csv', sep=";")

# %%
df_clima = pd.read_csv('C:/Users/Willian/Desktop/Radartona/bases_tratadas/clima_tratado.csv', sep=";")

# %%
df_clima = df_clima[['rain','ano','mes','dia']]

# %%
df_clima.head()
# Out:
#    rain   ano  mes  dia   merge
# 0     1  2015    1    1  201511
# 1     0  2015    1    1  201511
# 2     0  2015    1    1  201511
# 3     0  2015    1    1  201511
# 4     0  2015    1    1  201511

# %%
for index, row in df_clima.iterrows():
    ano, mes, dia = row["ano"],row['mes'],row['dia']
    
    df_clima.loc[index, 'merge'] = str(ano)+str(mes)+str(dia)

# %%
for index, row in df.iterrows():
    ano, mes, dia = row["ano"],row['mes'],row['dia']
    
    df.loc[index, 'merge'] = str(ano)+str(mes)+str(dia)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-64-bdfe452747ec> in <module>
# ----> 1 for index, row in df.iterrows():
#       2     ano, mes, dia = row["ano"],row['mes'],row['dia']
#       3
#       4     df.loc[index, 'merge'] = str(ano)+str(mes)+str(dia)
#
# c:\users\willian\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in iterrows(self)
#     906         columns = self.columns
#     907         klass = self._constructor_sliced
# --> 908         for k, v in zip(self.index, self.values):
#     909             s = klass(v, index=columns, name=k)
#     910             yield k, s
#
# c:\users\willian\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in values(self)
#    5441         """
#    5442         self._consolidate_inplace()
# ...

# %%
cruzamento_df = pd.merge(df, df_clima,  how='left', left_on=['ano','mes','dia'], right_on = ['ano','mes', 'dia'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-67-845a3597c56d> in <module>
# ----> 1 cruzamento_df = pd.merge(df, df_clima,  how='left', left_on=['ano','mes','dia'], right_on = ['ano','mes', 'dia'])
#
# c:\users\willian\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# c:\users\willian\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     640             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     641
# --> 642         join_index, left_indexer, right_indexer = self._get_join_info()
#     643
# ...

# %%
df['ano'].unique()
# Out:
# array([2019, 2018], dtype=int64)

# %%
df_clima = df_clima[df_clima['ano'] == 2018]

# %%
df_clima.head()
# Out:
#        rain   ano  mes  dia
# 26307     0  2018    1    1
# 26308     0  2018    1    1
# 26309     0  2018    1    1
# 26310     0  2018    1    1
# 26311     0  2018    1    1
