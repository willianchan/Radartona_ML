# %%
a = """R-F-A-P-VER
V-Z-PR
V-R-F-A-P
R-A-P-C
V-R-F-VER-EX
V-R-Z
R-Z-F- C
V-VR-EX
A
VER-V-R-A-P
V-R-F-VR
V-R-Z-F-A-P
V-R-F-EX-VER
V-EX
V- EX
V-R-F-Z
V-R-EX-VER-F
VER-V-A-P
V-R-VER-Z-EX
V-R-EX-F-VER
V-R-VER-A-P
R-A-P
V-R-F-Z-EX
V-R-PR-MOTO-VER
R-Z-F
V-R-VER
R-F-Z-A-P
V-A-P-R-Z
VR-V-R-EX-F
VER-V-R-F
V - EX
R-A-P-VER
V-R-PR-VER
VER-V-R-F-A-P
V-R-A-P-VER
A-P-C
F-A-P-VER
V-EX-R-VER
A-P-R-Z-F
V-VER-PR
V-R-Z-EX
V-R-F-EX- VER
R-VER
VER-V
V
V-R-EX-VER
A-P
V-PR
V-R-F-A-P-VER
V-R-F-Z-A-P
V-PR-VER
VER-V-R-PR
V-A-P
V-A
EX
V-R-VER-EX
V-R-F-VER
VER-V-R-A
V-R-PR-MOTO
VER-V-R
V-R-VR-PR-MOTO
V-A-C
R-Z-C
V- R-Z-F-A-P
VER-V-R-EX-F
V-R-EX
V-R-Z-F
V-R-PR
V-R-MOTO-VER
R-Z-F- CP
R-Z-F-C
V-R-VER-F-EX
V-R-Z-PR
V-R-Z-A-P
V-R

R
V-VER
V-R-VER-PR-MOTO
V-R-VER-PR
R-Z-F-A-P
C
V-EX-VER
R-Z-F-EX
V-R-Z-F-EX
V-R-Z-F-A
V-EX-VR
R-Z
V-R-F-Z-C
V-R-VR
V-R-A-P
VER-V-R-EX"""

# %%
a = a.split("\n")

# %%
b=[]
for i in a:
    i.replace(" ","")
    c = i.split("-")
    for j in c:
        b.append(j.replace(" ",""))

# %%
b
# Out:
# ['R',
#  'F',
#  'A',
#  'P',
#  'VER',
#  'V',
#  'Z',
#  'PR',
#  'V',
#  'R',
#  'F',
#  'A',
#  'P',
#  'R',
#  'A',
#  'P',
#  'C',
#  'V',
#  'R',
#  'F',
#  'VER',
#  'EX',
#  'V',
#  'R',
#  'Z',
#  'R',
#  'Z',
#  'F',
#  'C',
#  'V',
#  'VR',
#  'EX',
#  'A',
#  'VER',
#  'V',
#  'R',
#  'A',
#  'P',
#  'V',
#  'R',
#  'F',
#  'VR',
#  'V',
#  'R',
#  'Z',
#  'F',
#  'A',
#  'P',
#  'V',
#  'R',
#  'F',
#  'EX',
#  'VER',
#  'V',
#  'EX',
#  'V',
#  'EX',
#  'V',
#  'R',
#  'F',
#  'Z',
#  'V',
#  'R',
#  'EX',
#  'VER',
#  'F',
#  'VER',
#  'V',
#  'A',
#  'P',
#  'V',
#  'R',
#  'VER',
#  'Z',
#  'EX',
#  'V',
#  'R',
#  'EX',
#  'F',
#  'VER',
#  'V',
#  'R',
#  'VER',
#  'A',
#  'P',
#  'R',
#  'A',
#  'P',
#  'V',
#  'R',
#  'F',
#  'Z',
#  'EX',
#  'V',
#  'R',
#  'PR',
#  'MOTO',
#  'VER',
#  'R',
#  'Z',
#  'F',
#  'V',
#  'R',
#  'VER',
#  'R',
#  'F',
#  'Z',
#  'A',
#  'P',
#  'V',
#  'A',
#  'P',
#  'R',
#  'Z',
#  'VR',
#  'V',
#  'R',
#  'EX',
#  'F',
# ...

# %%
saida = set(b)

# %%
saida
# Out:
# {'', 'A', 'C', 'CP', 'EX', 'F', 'MOTO', 'P', 'PR', 'R', 'V', 'VER', 'VR', 'Z'}
